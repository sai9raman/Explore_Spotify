# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

# %%
class SpotifyAPI(object):
    access_token=None
    access_token_expiry = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = 'https://accounts.spotify.com/api/token'
    
    def __init__(self,client_id,client_secret,*args,**kwargs):
        super().__init__(*args,**kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        """
        Returns a base64 encoded STRING
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception ("You must set client Id and client secret ")
        client_creds = f'{client_id}:{client_secret}'
        client_creds_b64 = base64.b64encode(client_creds.encode())
        
        return client_creds_b64.decode()
        
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
    "Authorization": f"Basic {client_creds_b64}" 
}
    
    def get_token_data(self):
        return {
    "grant_type":"client_credentials"
}
    
    def perform_auth(self):
        
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        
        r = requests.post(token_url,data=token_data,headers=token_headers)
        
        if r.status_code not in range(200,299):
            raise Exception("Authentication failed")
        
        data = r.json()
        now = datetime.datetime.now()
        self.access_token = data['access_token']
        expires_in = data['expires_in'] #in seconds
        expiry = now+datetime.timedelta(seconds=expires_in)
        self.access_token_expiry = expiry
        self.access_token_did_expire = expiry<now
        
        return True
     
    def get_access_token(self):

        token = self.access_token
        expires = self.access_token_expiry
        now = datetime.datetime.now()
        if expires<now or token==None:
            self.perform_auth()
            return self.get_access_token()
        
        return token
    
    def get_resource_headers(self):
        access_token = self.get_access_token()
        
        headers = { 
            'Authorization':f'Bearer {access_token}'
        }
        return headers
        
    def get_resource(self, lookup_id, resource_type='albums',version='v1'):
        endpoint = f'https://api.spotify.com/{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_headers()
        r = requests.get(endpoint,headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
        
    def get_album(self,_id):
        return self.get_resource(_id,resource_type="albums")
    
    def get_artist(self,_id):
        return self.get_resource(_id,resource_type="artists")
    
    def base_search(self,query_params):
        
        headers = self.get_resource_headers()
        endpoint = 'https://api.spotify.com/v1/search'     
        lookup_url = f'{endpoint}?{query_params}'
        r=requests.get(lookup_url, headers=headers)
        if r.status_code not in range (200,299):
            return {}
        
        return r.json()
    
    def search(self, query=None, operator=None, operator_query = None, search_type='artist'):
        
        if query is None: 
            raise Exception ("A query is required")
        
        if isinstance(query,dict):
            query = " ".join([f'{k}:{v}' for k,v in query.items()])
        
        if operator!=None and operator_query!=None:
            if operator.lower() =='or' or operator.lower()=='not':
                operator=operator.upper()
                if isinstance(operator_query,str):
                    query=f'{query} {operator} {operator_query}'
            
        query_params = urlencode({"q":query,"type":search_type.lower()})
        print(query_params)
        return self.base_search(query_params)

# %% [markdown]
# ## Using the above class to do some stuff

# %%
import os

client_id = os.environ['SPOTIFY_CID']
client_secret = os.environ['SPOTIFY_CS']

# %%
spotify = SpotifyAPI(client_id,client_secret)

# %%
spotify.search({"track":"Teental", "artist": "Zakir Hussain"}, search_type="track")
# Out:
# q=track%3ATeental+artist%3AZakir+Hussain&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3ATeental+artist%3AZakir+Hussain&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jGk8eDMQBWb1IjNLI51Yz'},
#        'href': 'https://api.spotify.com/v1/artists/6jGk8eDMQBWb1IjNLI51Yz',
#        'id': '6jGk8eDMQBWb1IjNLI51Yz',
#        'name': 'G.S. Sachdev',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jGk8eDMQBWb1IjNLI51Yz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1lb96XcU7VPw6lMlYBZjOZ'},
#      'href': 'https://api.spotify.com/v1/albums/1lb96XcU7VPw6lMlYBZjOZ',
#      'id': '1lb96XcU7VPw6lMlYBZjOZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b89099cbd9317fa318bfc284',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b89099cbd9317fa318bfc284',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b89099cbd9317fa318bfc284',
#        'width': 64}],
#      'name': 'Spirit',
#      'release_date': '1991-08-01',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:1lb96XcU7VPw6lMlYBZjOZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DDCjHWtL6jTl1B5wG8tF6'},
#       'href': 'https://api.spotify.com/v1/artists/6DDCjHWtL6jTl1B5wG8tF6',
#       'id': '6DDCjHWtL6jTl1B5wG8tF6',
#       'name': 'Zakir Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:6DDCjHWtL6jTl1B5wG8tF6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jGk8eDMQBWb1IjNLI51Yz'},
#       'href': 'https://api.spotify.com/v1/artists/6jGk8eDMQBWb1IjNLI51Yz',
#       'id': '6jGk8eDMQBWb1IjNLI51Yz',
#       'name': 'G.S. Sachdev',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jGk8eDMQBWb1IjNLI51Yz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 605453,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBCV9112903'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Mi4Xldwx0lCMWGmcMkzO3'},
#     'href': 'https://api.spotify.com/v1/tracks/4Mi4Xldwx0lCMWGmcMkzO3',
#     'id': '4Mi4Xldwx0lCMWGmcMkzO3',
#     'is_local': False,
#     'name': 'Rag Chandrakauns: drut teental',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9d452018d59166d420d5e3d83677b4c6ca3be51b?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4Mi4Xldwx0lCMWGmcMkzO3'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DDCjHWtL6jTl1B5wG8tF6'},
#        'href': 'https://api.spotify.com/v1/artists/6DDCjHWtL6jTl1B5wG8tF6',
#        'id': '6DDCjHWtL6jTl1B5wG8tF6',
#        'name': 'Zakir Hussain',
#        'type': 'artist',
#        'uri': 'spotify:artist:6DDCjHWtL6jTl1B5wG8tF6'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4ohBZT3YI77ie6Jss6LG48'},
#      'href': 'https://api.spotify.com/v1/albums/4ohBZT3YI77ie6Jss6LG48',
#      'id': '4ohBZT3YI77ie6Jss6LG48',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d60d5dac4c6d4928514803c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d60d5dac4c6d4928514803c1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d60d5dac4c6d4928514803c1',
#        'width': 64}],
#      'name': 'Rough Guide to Zakir Hussain',
#      'release_date': '2018-07-27',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:4ohBZT3YI77ie6Jss6LG48'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DDCjHWtL6jTl1B5wG8tF6'},
#       'href': 'https://api.spotify.com/v1/artists/6DDCjHWtL6jTl1B5wG8tF6',
#       'id': '6DDCjHWtL6jTl1B5wG8tF6',
#       'name': 'Zakir Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:6DDCjHWtL6jTl1B5wG8tF6'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 1427293,
#     'explicit': False,
#     'external_ids': {'isrc': 'INH100512149'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6GWPok7yCd6A6lLmQhhNyk'},
#     'href': 'https://api.spotify.com/v1/tracks/6GWPok7yCd6A6lLmQhhNyk',
#     'id': '6GWPok7yCd6A6lLmQhhNyk',
#     'is_local': False,
#     'name': 'Punjabi Dhamar - Teental (Drut) Mishra Ghara',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7ce2464c4f0d50d2d5a2183218d4e43efeec61e5?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6GWPok7yCd6A6lLmQhhNyk'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Gypy00T57lgC7yWaGhNmS'},
#        'href': 'https://api.spotify.com/v1/artists/4Gypy00T57lgC7yWaGhNmS',
#        'id': '4Gypy00T57lgC7yWaGhNmS',
#        'name': 'Vilayat Khan',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Gypy00T57lgC7yWaGhNmS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1N5f8CaxiPz7iQFfSHMJnL'},
#      'href': 'https://api.spotify.com/v1/albums/1N5f8CaxiPz7iQFfSHMJnL',
#      'id': '1N5f8CaxiPz7iQFfSHMJnL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27382f1c64411d54db4cfd25bd3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0282f1c64411d54db4cfd25bd3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485182f1c64411d54db4cfd25bd3',
#        'width': 64}],
#      'name': 'Tradition',
#      'release_date': '2011-03-01',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:1N5f8CaxiPz7iQFfSHMJnL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DDCjHWtL6jTl1B5wG8tF6'},
#       'href': 'https://api.spotify.com/v1/artists/6DDCjHWtL6jTl1B5wG8tF6',
#       'id': '6DDCjHWtL6jTl1B5wG8tF6',
#       'name': 'Zakir Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:6DDCjHWtL6jTl1B5wG8tF6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5dS88NsHBp2oSt2tz3vFIX'},
#       'href': 'https://api.spotify.com/v1/artists/5dS88NsHBp2oSt2tz3vFIX',
#       'id': '5dS88NsHBp2oSt2tz3vFIX',
#       'name': 'Hidayat Khan',
#       'type': 'artist',
#       'uri': 'spotify:artist:5dS88NsHBp2oSt2tz3vFIX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1357853,
#     'explicit': False,
#     'external_ids': {'isrc': 'USXNY1100006'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2HPPdohUwNYm6NTQZ3Xbur'},
#     'href': 'https://api.spotify.com/v1/tracks/2HPPdohUwNYm6NTQZ3Xbur',
#     'id': '2HPPdohUwNYm6NTQZ3Xbur',
#     'is_local': False,
#     'name': 'Raga: Marwa (Gat in Teental)',
#     'popularity': 2,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3b60de00ac4f68c49535d86673f570b9c8ffa911?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2HPPdohUwNYm6NTQZ3Xbur'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jGk8eDMQBWb1IjNLI51Yz'},
#        'href': 'https://api.spotify.com/v1/artists/6jGk8eDMQBWb1IjNLI51Yz',
#        'id': '6jGk8eDMQBWb1IjNLI51Yz',
#        'name': 'G.S. Sachdev',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jGk8eDMQBWb1IjNLI51Yz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1lb96XcU7VPw6lMlYBZjOZ'},
#      'href': 'https://api.spotify.com/v1/albums/1lb96XcU7VPw6lMlYBZjOZ',
#      'id': '1lb96XcU7VPw6lMlYBZjOZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b89099cbd9317fa318bfc284',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b89099cbd9317fa318bfc284',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b89099cbd9317fa318bfc284',
#        'width': 64}],
#      'name': 'Spirit',
#      'release_date': '1991-08-01',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:1lb96XcU7VPw6lMlYBZjOZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DDCjHWtL6jTl1B5wG8tF6'},
#       'href': 'https://api.spotify.com/v1/artists/6DDCjHWtL6jTl1B5wG8tF6',
#       'id': '6DDCjHWtL6jTl1B5wG8tF6',
#       'name': 'Zakir Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:6DDCjHWtL6jTl1B5wG8tF6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jGk8eDMQBWb1IjNLI51Yz'},
#       'href': 'https://api.spotify.com/v1/artists/6jGk8eDMQBWb1IjNLI51Yz',
#       'id': '6jGk8eDMQBWb1IjNLI51Yz',
#       'name': 'G.S. Sachdev',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jGk8eDMQBWb1IjNLI51Yz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1820773,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBCV9112901'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6arwJFWbsvpvYlRYplqcMy'},
#     'href': 'https://api.spotify.com/v1/tracks/6arwJFWbsvpvYlRYplqcMy',
#     'id': '6arwJFWbsvpvYlRYplqcMy',
#     'is_local': False,
#     'name': 'Rag Bihag: Vilambit Ektal, drut teental',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b545a066246896f8fe386bb9472ee1860f563594?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6arwJFWbsvpvYlRYplqcMy'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DDCjHWtL6jTl1B5wG8tF6'},
#        'href': 'https://api.spotify.com/v1/artists/6DDCjHWtL6jTl1B5wG8tF6',
#        'id': '6DDCjHWtL6jTl1B5wG8tF6',
#        'name': 'Zakir Hussain',
#        'type': 'artist',
#        'uri': 'spotify:artist:6DDCjHWtL6jTl1B5wG8tF6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7DB7d9yCfmS5yY7bxraoFa'},
#      'href': 'https://api.spotify.com/v1/albums/7DB7d9yCfmS5yY7bxraoFa',
#      'id': '7DB7d9yCfmS5yY7bxraoFa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731e6b2c9bbabb75ffcc248d93',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021e6b2c9bbabb75ffcc248d93',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511e6b2c9bbabb75ffcc248d93',
#        'width': 64}],
#      'name': 'Taras: The Longing',
#      'release_date': '2010-11-25',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:7DB7d9yCfmS5yY7bxraoFa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DDCjHWtL6jTl1B5wG8tF6'},
#       'href': 'https://api.spotify.com/v1/artists/6DDCjHWtL6jTl1B5wG8tF6',
#       'id': '6DDCjHWtL6jTl1B5wG8tF6',
#       'name': 'Zakir Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:6DDCjHWtL6jTl1B5wG8tF6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2eOZNXw0A4cQKmsVPpIcMY'},
#       'href': 'https://api.spotify.com/v1/artists/2eOZNXw0A4cQKmsVPpIcMY',
#       'id': '2eOZNXw0A4cQKmsVPpIcMY',
#       'name': 'Sultan Khan',
#       'type': 'artist',
#       'uri': 'spotify:artist:2eOZNXw0A4cQKmsVPpIcMY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1470760,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6V80737379'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7fOJYPjLFZkRQzR2Ct8TG0'},
#     'href': 'https://api.spotify.com/v1/tracks/7fOJYPjLFZkRQzR2Ct8TG0',
#     'id': '7fOJYPjLFZkRQzR2Ct8TG0',
#     'is_local': False,
#     'name': 'Raga purya kalyan : Drut gat in teental',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1c1272e2a4d696f440ac89e2729cb9c05fbea7c7?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7fOJYPjLFZkRQzR2Ct8TG0'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FAYKYHVg00kY3aDd0Xu5N'},
#        'href': 'https://api.spotify.com/v1/artists/5FAYKYHVg00kY3aDd0Xu5N',
#        'id': '5FAYKYHVg00kY3aDd0Xu5N',
#        'name': 'Hariprasad Chaurasia, Pandit Jasraj & Zakir Hussain',
#        'type': 'artist',
#        'uri': 'spotify:artist:5FAYKYHVg00kY3aDd0Xu5N'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5zGo4Q2HAxOyzJUY4GVto1'},
#      'href': 'https://api.spotify.com/v1/albums/5zGo4Q2HAxOyzJUY4GVto1',
#      'id': '5zGo4Q2HAxOyzJUY4GVto1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737f9c259f3a1de1bdaba82d79',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027f9c259f3a1de1bdaba82d79',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517f9c259f3a1de1bdaba82d79',
#        'width': 64}],
#      'name': 'In Concert, Vol. II',
#      'release_date': '1996',
#      'release_date_precision': 'year',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:5zGo4Q2HAxOyzJUY4GVto1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FAYKYHVg00kY3aDd0Xu5N'},
#       'href': 'https://api.spotify.com/v1/artists/5FAYKYHVg00kY3aDd0Xu5N',
#       'id': '5FAYKYHVg00kY3aDd0Xu5N',
#       'name': 'Hariprasad Chaurasia, Pandit Jasraj & Zakir Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:5FAYKYHVg00kY3aDd0Xu5N'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 588773,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA370662151'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4yfe33sonNKbZc6VM3LNhg'},
#     'href': 'https://api.spotify.com/v1/tracks/4yfe33sonNKbZc6VM3LNhg',
#     'id': '4yfe33sonNKbZc6VM3LNhg',
#     'is_local': False,
#     'name': 'Teental',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/760289e0d2989123831bde84c188f6796e22b4b0?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4yfe33sonNKbZc6VM3LNhg'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25kj6LhAR0yqVJv26cZr3Q'},
#        'href': 'https://api.spotify.com/v1/artists/25kj6LhAR0yqVJv26cZr3Q',
#        'id': '25kj6LhAR0yqVJv26cZr3Q',
#        'name': 'Ustad Sultan Khan & Ustad Zakir Hussain',
#        'type': 'artist',
#        'uri': 'spotify:artist:25kj6LhAR0yqVJv26cZr3Q'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3jw1mTDNk1H3tSLOlrOkdG'},
#      'href': 'https://api.spotify.com/v1/albums/3jw1mTDNk1H3tSLOlrOkdG',
#      'id': '3jw1mTDNk1H3tSLOlrOkdG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733ec4e65451d463fb8f13dd06',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023ec4e65451d463fb8f13dd06',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513ec4e65451d463fb8f13dd06',
#        'width': 64}],
#      'name': 'Taras - The Longing',
#      'release_date': '2006-07-25',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:3jw1mTDNk1H3tSLOlrOkdG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25kj6LhAR0yqVJv26cZr3Q'},
#       'href': 'https://api.spotify.com/v1/artists/25kj6LhAR0yqVJv26cZr3Q',
#       'id': '25kj6LhAR0yqVJv26cZr3Q',
#       'name': 'Ustad Sultan Khan & Ustad Zakir Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:25kj6LhAR0yqVJv26cZr3Q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1622800,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA370664607'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3i7USP1Tn99DwhKySHLnbm'},
#     'href': 'https://api.spotify.com/v1/tracks/3i7USP1Tn99DwhKySHLnbm',
#     'id': '3i7USP1Tn99DwhKySHLnbm',
#     'is_local': False,
#     'name': 'Raga Puriya Kalyan: Vilambit Gat In Teental',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3651a8b0983a4a1a282ff7f3d567cf14932148d8?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3i7USP1Tn99DwhKySHLnbm'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25kj6LhAR0yqVJv26cZr3Q'},
#        'href': 'https://api.spotify.com/v1/artists/25kj6LhAR0yqVJv26cZr3Q',
#        'id': '25kj6LhAR0yqVJv26cZr3Q',
#        'name': 'Ustad Sultan Khan & Ustad Zakir Hussain',
#        'type': 'artist',
#        'uri': 'spotify:artist:25kj6LhAR0yqVJv26cZr3Q'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3jw1mTDNk1H3tSLOlrOkdG'},
#      'href': 'https://api.spotify.com/v1/albums/3jw1mTDNk1H3tSLOlrOkdG',
#      'id': '3jw1mTDNk1H3tSLOlrOkdG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733ec4e65451d463fb8f13dd06',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023ec4e65451d463fb8f13dd06',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513ec4e65451d463fb8f13dd06',
#        'width': 64}],
#      'name': 'Taras - The Longing',
#      'release_date': '2006-07-25',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:3jw1mTDNk1H3tSLOlrOkdG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25kj6LhAR0yqVJv26cZr3Q'},
#       'href': 'https://api.spotify.com/v1/artists/25kj6LhAR0yqVJv26cZr3Q',
#       'id': '25kj6LhAR0yqVJv26cZr3Q',
#       'name': 'Ustad Sultan Khan & Ustad Zakir Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:25kj6LhAR0yqVJv26cZr3Q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1470760,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA370664608'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3xhCevQu7dUCtKS7D8ZxXz'},
#     'href': 'https://api.spotify.com/v1/tracks/3xhCevQu7dUCtKS7D8ZxXz',
#     'id': '3xhCevQu7dUCtKS7D8ZxXz',
#     'is_local': False,
#     'name': 'Raga Puriya Kalyan: Drut Gat In Teental',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/257795aab3b9c10f663dd8f96fddfad33e2a487b?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3xhCevQu7dUCtKS7D8ZxXz'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 8}}

# %%
#spotify.get_artist('2MphKCPv2wbV61u03gKP4i')

# %%
#spotify.get_album('5CfytRni4jhBrwM2MdPg1N')

# %%
spotify.search(query="Teental",operator="NOT",operator_query="Zakir Hussain", search_type="track")
# Out:
# q=Teental+NOT+Zakir+Hussain&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Teental+NOT+Zakir+Hussain&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4sDAs9eLpnKTfMpE6MW9by'},
#        'href': 'https://api.spotify.com/v1/artists/4sDAs9eLpnKTfMpE6MW9by',
#        'id': '4sDAs9eLpnKTfMpE6MW9by',
#        'name': 'Kees Van Boxtel',
#        'type': 'artist',
#        'uri': 'spotify:artist:4sDAs9eLpnKTfMpE6MW9by'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6RqtBFM05dFkROC1Buhxdj'},
#      'href': 'https://api.spotify.com/v1/albums/6RqtBFM05dFkROC1Buhxdj',
#      'id': '6RqtBFM05dFkROC1Buhxdj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273452bd3a4e02a80b6781e60a0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02452bd3a4e02a80b6781e60a0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851452bd3a4e02a80b6781e60a0',
#        'width': 64}],
#      'name': 'Midnight Ragas for Meditation',
#      'release_date': '2019-08-29',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:6RqtBFM05dFkROC1Buhxdj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4sDAs9eLpnKTfMpE6MW9by'},
#       'href': 'https://api.spotify.com/v1/artists/4sDAs9eLpnKTfMpE6MW9by',
#       'id': '4sDAs9eLpnKTfMpE6MW9by',
#       'name': 'Kees Van Boxtel',
#       'type': 'artist',
#       'uri': 'spotify:artist:4sDAs9eLpnKTfMpE6MW9by'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6lq6y6gyGMHgQzxjIXw2nT'},
#       'href': 'https://api.spotify.com/v1/artists/6lq6y6gyGMHgQzxjIXw2nT',
#       'id': '6lq6y6gyGMHgQzxjIXw2nT',
#       'name': 'Shabbir Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:6lq6y6gyGMHgQzxjIXw2nT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 466830,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHN31981159'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5fIHUXkrkShjyk7Dljg7ZH'},
#     'href': 'https://api.spotify.com/v1/tracks/5fIHUXkrkShjyk7Dljg7ZH',
#     'id': '5fIHUXkrkShjyk7Dljg7ZH',
#     'is_local': False,
#     'name': 'Raga Malkauns (Teental) [feat. Shabbir Hussain]',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cbbc263933c83f124b438b024bd18eca09ac5c25?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5fIHUXkrkShjyk7Dljg7ZH'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4RoJBiLd92ZA26JLhdbLpZ'},
#        'href': 'https://api.spotify.com/v1/artists/4RoJBiLd92ZA26JLhdbLpZ',
#        'id': '4RoJBiLd92ZA26JLhdbLpZ',
#        'name': 'Ustad Irshad Hussain Khan',
#        'type': 'artist',
#        'uri': 'spotify:artist:4RoJBiLd92ZA26JLhdbLpZ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2jEajBLUPvXuccmxCc9kdK'},
#      'href': 'https://api.spotify.com/v1/albums/2jEajBLUPvXuccmxCc9kdK',
#      'id': '2jEajBLUPvXuccmxCc9kdK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d596b1823191a2b72d030109',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d596b1823191a2b72d030109',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d596b1823191a2b72d030109',
#        'width': 64}],
#      'name': 'Divine Rhythms on Tabla',
#      'release_date': '2000',
#      'release_date_precision': 'year',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:2jEajBLUPvXuccmxCc9kdK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4RoJBiLd92ZA26JLhdbLpZ'},
#       'href': 'https://api.spotify.com/v1/artists/4RoJBiLd92ZA26JLhdbLpZ',
#       'id': '4RoJBiLd92ZA26JLhdbLpZ',
#       'name': 'Ustad Irshad Hussain Khan',
#       'type': 'artist',
#       'uri': 'spotify:artist:4RoJBiLd92ZA26JLhdbLpZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1914933,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLC190000331'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1fvfWr2B8LfpWz6j1G35UR'},
#     'href': 'https://api.spotify.com/v1/tracks/1fvfWr2B8LfpWz6j1G35UR',
#     'id': '1fvfWr2B8LfpWz6j1G35UR',
#     'is_local': False,
#     'name': 'Teental',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/380852085df4173a17ba6353fda52d9a4b054088?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1fvfWr2B8LfpWz6j1G35UR'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7p08ER923tC5seYgfsfyO9'},
#      'href': 'https://api.spotify.com/v1/albums/7p08ER923tC5seYgfsfyO9',
#      'id': '7p08ER923tC5seYgfsfyO9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273faeea9f7c342442a11ae40bd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02faeea9f7c342442a11ae40bd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851faeea9f7c342442a11ae40bd',
#        'width': 64}],
#      'name': 'North India: Instrumental Music - Sitar, Flute, Sarangi',
#      'release_date': '2015-07-14',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:7p08ER923tC5seYgfsfyO9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7IWB7jdIt5PQ01MrmZPm8F'},
#       'href': 'https://api.spotify.com/v1/artists/7IWB7jdIt5PQ01MrmZPm8F',
#       'id': '7IWB7jdIt5PQ01MrmZPm8F',
#       'name': 'Ghulam Hussain Khan',
#       'type': 'artist',
#       'uri': 'spotify:artist:7IWB7jdIt5PQ01MrmZPm8F'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/24fC6QbMA6BBvdL3cIoqGL'},
#       'href': 'https://api.spotify.com/v1/artists/24fC6QbMA6BBvdL3cIoqGL',
#       'id': '24fC6QbMA6BBvdL3cIoqGL',
#       'name': 'Nizamuddin Khan',
#       'type': 'artist',
#       'uri': 'spotify:artist:24fC6QbMA6BBvdL3cIoqGL'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2iolNJQemMhOt7v85oLnZ4'},
#       'href': 'https://api.spotify.com/v1/artists/2iolNJQemMhOt7v85oLnZ4',
#       'id': '2iolNJQemMhOt7v85oLnZ4',
#       'name': 'Pratima S. Parekh',
#       'type': 'artist',
#       'uri': 'spotify:artist:2iolNJQemMhOt7v85oLnZ4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1657426,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSF11201701'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2FeecehtalzB3Mrps0obJN'},
#     'href': 'https://api.spotify.com/v1/tracks/2FeecehtalzB3Mrps0obJN',
#     'id': '2FeecehtalzB3Mrps0obJN',
#     'is_local': False,
#     'name': 'Raga Desh: Teentala',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/958adb69ffc752bc9886103f5b099da4b6a7f256?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2FeecehtalzB3Mrps0obJN'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16jxGPGytwKc6TLwGhJ6XL'},
#        'href': 'https://api.spotify.com/v1/artists/16jxGPGytwKc6TLwGhJ6XL',
#        'id': '16jxGPGytwKc6TLwGhJ6XL',
#        'name': 'Shahbaz Hussain',
#        'type': 'artist',
#        'uri': 'spotify:artist:16jxGPGytwKc6TLwGhJ6XL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Q3JjCxophPZ7OCJx8vYNZ'},
#      'href': 'https://api.spotify.com/v1/albums/6Q3JjCxophPZ7OCJx8vYNZ',
#      'id': '6Q3JjCxophPZ7OCJx8vYNZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27380fa3bba288fcaf53f07463f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0280fa3bba288fcaf53f07463f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485180fa3bba288fcaf53f07463f',
#        'width': 64}],
#      'name': 'Tabla Solo Recital',
#      'release_date': '2007-12-31',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:6Q3JjCxophPZ7OCJx8vYNZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16jxGPGytwKc6TLwGhJ6XL'},
#       'href': 'https://api.spotify.com/v1/artists/16jxGPGytwKc6TLwGhJ6XL',
#       'id': '16jxGPGytwKc6TLwGhJ6XL',
#       'name': 'Shahbaz Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:16jxGPGytwKc6TLwGhJ6XL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1704440,
#     'explicit': False,
#     'external_ids': {'isrc': 'usl4r0732688'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0WZ1izNkXdCEKbDGivi4Uy'},
#     'href': 'https://api.spotify.com/v1/tracks/0WZ1izNkXdCEKbDGivi4Uy',
#     'id': '0WZ1izNkXdCEKbDGivi4Uy',
#     'is_local': False,
#     'name': 'Vilambit Teental - 16 Beats',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c619b7c46c52bcfcae57acc3fa559022b6a7b3fc?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0WZ1izNkXdCEKbDGivi4Uy'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16jxGPGytwKc6TLwGhJ6XL'},
#        'href': 'https://api.spotify.com/v1/artists/16jxGPGytwKc6TLwGhJ6XL',
#        'id': '16jxGPGytwKc6TLwGhJ6XL',
#        'name': 'Shahbaz Hussain',
#        'type': 'artist',
#        'uri': 'spotify:artist:16jxGPGytwKc6TLwGhJ6XL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Q3JjCxophPZ7OCJx8vYNZ'},
#      'href': 'https://api.spotify.com/v1/albums/6Q3JjCxophPZ7OCJx8vYNZ',
#      'id': '6Q3JjCxophPZ7OCJx8vYNZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27380fa3bba288fcaf53f07463f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0280fa3bba288fcaf53f07463f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485180fa3bba288fcaf53f07463f',
#        'width': 64}],
#      'name': 'Tabla Solo Recital',
#      'release_date': '2007-12-31',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:6Q3JjCxophPZ7OCJx8vYNZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16jxGPGytwKc6TLwGhJ6XL'},
#       'href': 'https://api.spotify.com/v1/artists/16jxGPGytwKc6TLwGhJ6XL',
#       'id': '16jxGPGytwKc6TLwGhJ6XL',
#       'name': 'Shahbaz Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:16jxGPGytwKc6TLwGhJ6XL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 728120,
#     'explicit': False,
#     'external_ids': {'isrc': 'usl4r0732690'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1QO0DqvDguKNteLz7HcEP1'},
#     'href': 'https://api.spotify.com/v1/tracks/1QO0DqvDguKNteLz7HcEP1',
#     'id': '1QO0DqvDguKNteLz7HcEP1',
#     'is_local': False,
#     'name': 'Drut Teental - Fast 16 Beats',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4da73bde1cc1f479e1e6febd64ffd892d7c4499b?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1QO0DqvDguKNteLz7HcEP1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K865VVkKXycOsnM5E64dY'},
#        'href': 'https://api.spotify.com/v1/artists/5K865VVkKXycOsnM5E64dY',
#        'id': '5K865VVkKXycOsnM5E64dY',
#        'name': 'Ustad Vilayat Khan, Shujaat Hussain',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K865VVkKXycOsnM5E64dY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/08mEd0IxXzRmRZbgKOKyEu'},
#      'href': 'https://api.spotify.com/v1/albums/08mEd0IxXzRmRZbgKOKyEu',
#      'id': '08mEd0IxXzRmRZbgKOKyEu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fc5be85b672aa3c14077ee36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fc5be85b672aa3c14077ee36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fc5be85b672aa3c14077ee36',
#        'width': 64}],
#      'name': 'Live at the Royal Festival Hall, London, November 25, 1993',
#      'release_date': '1995-09-01',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:08mEd0IxXzRmRZbgKOKyEu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K865VVkKXycOsnM5E64dY'},
#       'href': 'https://api.spotify.com/v1/artists/5K865VVkKXycOsnM5E64dY',
#       'id': '5K865VVkKXycOsnM5E64dY',
#       'name': 'Ustad Vilayat Khan, Shujaat Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K865VVkKXycOsnM5E64dY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 1072440,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560856479'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/07qXcu405vRVYxNS0yoYyc'},
#     'href': 'https://api.spotify.com/v1/tracks/07qXcu405vRVYxNS0yoYyc',
#     'id': '07qXcu405vRVYxNS0yoYyc',
#     'is_local': False,
#     'name': 'Raga Shahana - Vilambit Gat In Teental',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cc26d6d31903deb7f184642eb326dde9ae337ae0?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:07qXcu405vRVYxNS0yoYyc'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K865VVkKXycOsnM5E64dY'},
#        'href': 'https://api.spotify.com/v1/artists/5K865VVkKXycOsnM5E64dY',
#        'id': '5K865VVkKXycOsnM5E64dY',
#        'name': 'Ustad Vilayat Khan, Shujaat Hussain',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K865VVkKXycOsnM5E64dY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/08mEd0IxXzRmRZbgKOKyEu'},
#      'href': 'https://api.spotify.com/v1/albums/08mEd0IxXzRmRZbgKOKyEu',
#      'id': '08mEd0IxXzRmRZbgKOKyEu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fc5be85b672aa3c14077ee36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fc5be85b672aa3c14077ee36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fc5be85b672aa3c14077ee36',
#        'width': 64}],
#      'name': 'Live at the Royal Festival Hall, London, November 25, 1993',
#      'release_date': '1995-09-01',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:08mEd0IxXzRmRZbgKOKyEu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K865VVkKXycOsnM5E64dY'},
#       'href': 'https://api.spotify.com/v1/artists/5K865VVkKXycOsnM5E64dY',
#       'id': '5K865VVkKXycOsnM5E64dY',
#       'name': 'Ustad Vilayat Khan, Shujaat Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K865VVkKXycOsnM5E64dY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 1549000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560856480'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Bcpxs48dhOGQmdIug0dCa'},
#     'href': 'https://api.spotify.com/v1/tracks/3Bcpxs48dhOGQmdIug0dCa',
#     'id': '3Bcpxs48dhOGQmdIug0dCa',
#     'is_local': False,
#     'name': 'Raga Bageshree - Drut Bandish In Teental',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/69b219e22bac7acaa56b983aa4453707c92f8480?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3Bcpxs48dhOGQmdIug0dCa'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6YDQf46wm3QZg6TagNkwLz'},
#        'href': 'https://api.spotify.com/v1/artists/6YDQf46wm3QZg6TagNkwLz',
#        'id': '6YDQf46wm3QZg6TagNkwLz',
#        'name': 'Ustad Munir Khan (sarangi)',
#        'type': 'artist',
#        'uri': 'spotify:artist:6YDQf46wm3QZg6TagNkwLz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3OQSPh0G3R2jWIzDbElot6'},
#        'href': 'https://api.spotify.com/v1/artists/3OQSPh0G3R2jWIzDbElot6',
#        'id': '3OQSPh0G3R2jWIzDbElot6',
#        'name': 'Zamir Ahmad Khan (tabla)',
#        'type': 'artist',
#        'uri': 'spotify:artist:3OQSPh0G3R2jWIzDbElot6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Zsrpu2NG2xLaVy0jDqO7A'},
#      'href': 'https://api.spotify.com/v1/albums/2Zsrpu2NG2xLaVy0jDqO7A',
#      'id': '2Zsrpu2NG2xLaVy0jDqO7A',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733a3fa14ed41ebe6037886f36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023a3fa14ed41ebe6037886f36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513a3fa14ed41ebe6037886f36',
#        'width': 64}],
#      'name': 'Ananda - Classical sarangi music from North India',
#      'release_date': '2003',
#      'release_date_precision': 'year',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:2Zsrpu2NG2xLaVy0jDqO7A'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4jlHoeCDaWAgKvFyDiklZR'},
#       'href': 'https://api.spotify.com/v1/artists/4jlHoeCDaWAgKvFyDiklZR',
#       'id': '4jlHoeCDaWAgKvFyDiklZR',
#       'name': 'Ustad Munir Khan',
#       'type': 'artist',
#       'uri': 'spotify:artist:4jlHoeCDaWAgKvFyDiklZR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Q2OawYbpjB5tNOqODkbXm'},
#       'href': 'https://api.spotify.com/v1/artists/0Q2OawYbpjB5tNOqODkbXm',
#       'id': '0Q2OawYbpjB5tNOqODkbXm',
#       'name': 'Zamir Ahmad Khan',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Q2OawYbpjB5tNOqODkbXm'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7z9TqMvOI7ii6AR9q8AtQS'},
#       'href': 'https://api.spotify.com/v1/artists/7z9TqMvOI7ii6AR9q8AtQS',
#       'id': '7z9TqMvOI7ii6AR9q8AtQS',
#       'name': 'Inayat Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:7z9TqMvOI7ii6AR9q8AtQS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1572480,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLCL50200003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/07UWptSsIdU24Dv7lJJfwD'},
#     'href': 'https://api.spotify.com/v1/tracks/07UWptSsIdU24Dv7lJJfwD',
#     'id': '07UWptSsIdU24Dv7lJJfwD',
#     'is_local': False,
#     'name': 'Rageshri (vilambit ektal / drut teental)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6efbfedebc237bc770fc12dca3dda8bfb7e1f0c0?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:07UWptSsIdU24Dv7lJJfwD'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4sDAs9eLpnKTfMpE6MW9by'},
#        'href': 'https://api.spotify.com/v1/artists/4sDAs9eLpnKTfMpE6MW9by',
#        'id': '4sDAs9eLpnKTfMpE6MW9by',
#        'name': 'Kees Van Boxtel',
#        'type': 'artist',
#        'uri': 'spotify:artist:4sDAs9eLpnKTfMpE6MW9by'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1jHZD5DHGnhcb2XCmwx1pj'},
#        'href': 'https://api.spotify.com/v1/artists/1jHZD5DHGnhcb2XCmwx1pj',
#        'id': '1jHZD5DHGnhcb2XCmwx1pj',
#        'name': 'Joel Veena',
#        'type': 'artist',
#        'uri': 'spotify:artist:1jHZD5DHGnhcb2XCmwx1pj'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0ITRbBKiOZkU3eaWCOZUzn'},
#      'href': 'https://api.spotify.com/v1/albums/0ITRbBKiOZkU3eaWCOZUzn',
#      'id': '0ITRbBKiOZkU3eaWCOZUzn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a53bedbc482e1add5f9e48fe',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a53bedbc482e1add5f9e48fe',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a53bedbc482e1add5f9e48fe',
#        'width': 64}],
#      'name': 'Sacred Groves Live in Europe',
#      'release_date': '2019-08-16',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:0ITRbBKiOZkU3eaWCOZUzn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4sDAs9eLpnKTfMpE6MW9by'},
#       'href': 'https://api.spotify.com/v1/artists/4sDAs9eLpnKTfMpE6MW9by',
#       'id': '4sDAs9eLpnKTfMpE6MW9by',
#       'name': 'Kees Van Boxtel',
#       'type': 'artist',
#       'uri': 'spotify:artist:4sDAs9eLpnKTfMpE6MW9by'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1jHZD5DHGnhcb2XCmwx1pj'},
#       'href': 'https://api.spotify.com/v1/artists/1jHZD5DHGnhcb2XCmwx1pj',
#       'id': '1jHZD5DHGnhcb2XCmwx1pj',
#       'name': 'Joel Veena',
#       'type': 'artist',
#       'uri': 'spotify:artist:1jHZD5DHGnhcb2XCmwx1pj'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6lq6y6gyGMHgQzxjIXw2nT'},
#       'href': 'https://api.spotify.com/v1/artists/6lq6y6gyGMHgQzxjIXw2nT',
#       'id': '6lq6y6gyGMHgQzxjIXw2nT',
#       'name': 'Shabbir Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:6lq6y6gyGMHgQzxjIXw2nT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1061000,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZFZ31962913'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3TnlMLGEy4NpcDdAHLTW5i'},
#     'href': 'https://api.spotify.com/v1/tracks/3TnlMLGEy4NpcDdAHLTW5i',
#     'id': '3TnlMLGEy4NpcDdAHLTW5i',
#     'is_local': False,
#     'name': 'Raga Yaman Composition in Teental - Live',
#     'popularity': 2,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e07859142f45a244c12bd097fe5f6bec9be96127?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3TnlMLGEy4NpcDdAHLTW5i'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6YDQf46wm3QZg6TagNkwLz'},
#        'href': 'https://api.spotify.com/v1/artists/6YDQf46wm3QZg6TagNkwLz',
#        'id': '6YDQf46wm3QZg6TagNkwLz',
#        'name': 'Ustad Munir Khan (sarangi)',
#        'type': 'artist',
#        'uri': 'spotify:artist:6YDQf46wm3QZg6TagNkwLz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3OQSPh0G3R2jWIzDbElot6'},
#        'href': 'https://api.spotify.com/v1/artists/3OQSPh0G3R2jWIzDbElot6',
#        'id': '3OQSPh0G3R2jWIzDbElot6',
#        'name': 'Zamir Ahmad Khan (tabla)',
#        'type': 'artist',
#        'uri': 'spotify:artist:3OQSPh0G3R2jWIzDbElot6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Zsrpu2NG2xLaVy0jDqO7A'},
#      'href': 'https://api.spotify.com/v1/albums/2Zsrpu2NG2xLaVy0jDqO7A',
#      'id': '2Zsrpu2NG2xLaVy0jDqO7A',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733a3fa14ed41ebe6037886f36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023a3fa14ed41ebe6037886f36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513a3fa14ed41ebe6037886f36',
#        'width': 64}],
#      'name': 'Ananda - Classical sarangi music from North India',
#      'release_date': '2003',
#      'release_date_precision': 'year',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:2Zsrpu2NG2xLaVy0jDqO7A'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4jlHoeCDaWAgKvFyDiklZR'},
#       'href': 'https://api.spotify.com/v1/artists/4jlHoeCDaWAgKvFyDiklZR',
#       'id': '4jlHoeCDaWAgKvFyDiklZR',
#       'name': 'Ustad Munir Khan',
#       'type': 'artist',
#       'uri': 'spotify:artist:4jlHoeCDaWAgKvFyDiklZR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Q2OawYbpjB5tNOqODkbXm'},
#       'href': 'https://api.spotify.com/v1/artists/0Q2OawYbpjB5tNOqODkbXm',
#       'id': '0Q2OawYbpjB5tNOqODkbXm',
#       'name': 'Zamir Ahmad Khan',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Q2OawYbpjB5tNOqODkbXm'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7z9TqMvOI7ii6AR9q8AtQS'},
#       'href': 'https://api.spotify.com/v1/artists/7z9TqMvOI7ii6AR9q8AtQS',
#       'id': '7z9TqMvOI7ii6AR9q8AtQS',
#       'name': 'Inayat Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:7z9TqMvOI7ii6AR9q8AtQS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1291746,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLCL50200002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5xBOkapJHDfEu9xSkTSN00'},
#     'href': 'https://api.spotify.com/v1/tracks/5xBOkapJHDfEu9xSkTSN00',
#     'id': '5xBOkapJHDfEu9xSkTSN00',
#     'is_local': False,
#     'name': 'Nand Kalyan (drut ektal) / Shankara (drut teental)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/154246450669f6840642da7d22ebdb8f963a9ca6?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5xBOkapJHDfEu9xSkTSN00'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 10}}
