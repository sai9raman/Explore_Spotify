# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

# %%
class SpotifyAPI(object):
    access_token=None
    access_token_expiry = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = 'https://accounts.spotify.com/api/token'
    
    def __init__(self,client_id,client_secret,*args,**kwargs):
        super().__init__(*args,**kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        """
        Returns a base64 encoded STRING
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception ("You must set client Id and client secret ")
        client_creds = f'{client_id}:{client_secret}'
        client_creds_b64 = base64.b64encode(client_creds.encode())
        
        return client_creds_b64.decode()
        
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
    "Authorization": f"Basic {client_creds_b64}" 
}
    
    def get_token_data(self):
        return {
    "grant_type":"client_credentials"
}
    
    def perform_auth(self):
        
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        
        r = requests.post(token_url,data=token_data,headers=token_headers)
        
        if r.status_code not in range(200,299):
            raise Exception("Authentication failed")
        
        data = r.json()
        now = datetime.datetime.now()
        self.access_token = data['access_token']
        expires_in = data['expires_in'] #in seconds
        expiry = now+datetime.timedelta(seconds=expires_in)
        self.access_token_expiry = expiry
        self.access_token_did_expire = expiry<now
        
        return True
     
    def get_access_token(self):

        token = self.access_token
        expires = self.access_token_expiry
        now = datetime.datetime.now()
        if expires<now or token==None:
            self.perform_auth()
            return self.get_access_token()
        
        return token
    
    def get_resource_headers(self):
        access_token = self.get_access_token()
        
        headers = { 
            'Authorization':f'Bearer {access_token}'
        }
        return headers
        
    def get_resource(self, lookup_id, resource_type='albums',version='v1'):
        endpoint = f'https://api.spotify.com/{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_headers()
        r = requests.get(endpoint,headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
        
    def get_album(self,_id):
        return self.get_resource(_id,resource_type="albums")
    
    def get_artist(self,_id):
        return self.get_resource(_id,resource_type="artists")
    
    def search(self,query,search_type='artist'):
        
        headers = self.get_resource_headers()
        endpoint = 'https://api.spotify.com/v1/search'
        data = urlencode({"q":query,"type":search_type.lower()})

        lookup_url = f'{endpoint}?{data}'
        print(lookup_url)
        r=requests.get(lookup_url, headers=headers)
        if r.status_code not in range (200,299):
            return {}
        
        return r.json()

# %% [markdown]
# ## Using the above class to do some stuff

# %%
import os

client_id = os.environ['SPOTIFY_CID']
client_secret = os.environ['SPOTIFY_CS']

# %%
spotify = SpotifyAPI(client_id,client_secret)

# %%
spotify.search("Making Music",search_type="album")
# Out:
# https://api.spotify.com/v1/search?q=Making+Music&type=album
# {'albums': {'href': 'https://api.spotify.com/v1/search?query=Making+Music&type=album&offset=0&limit=20',
#   'items': [{'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#       'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#       'id': '1ThoqLcyIYvZn7iWbj8fsj',
#       'name': 'Bill Withers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5CfytRni4jhBrwM2MdPg1N'},
#     'href': 'https://api.spotify.com/v1/albums/5CfytRni4jhBrwM2MdPg1N',
#     'id': '5CfytRni4jhBrwM2MdPg1N',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736387564c694f2d017a3554b6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026387564c694f2d017a3554b6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516387564c694f2d017a3554b6',
#       'width': 64}],
#     'name': 'Making Music',
#     'release_date': '1975-11-08',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5CfytRni4jhBrwM2MdPg1N'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6DDCjHWtL6jTl1B5wG8tF6'},
#       'href': 'https://api.spotify.com/v1/artists/6DDCjHWtL6jTl1B5wG8tF6',
#       'id': '6DDCjHWtL6jTl1B5wG8tF6',
#       'name': 'Zakir Hussain',
#       'type': 'artist',
#       'uri': 'spotify:artist:6DDCjHWtL6jTl1B5wG8tF6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6Z5RRaRtxckdDY9W9711lB'},
#     'href': 'https://api.spotify.com/v1/albums/6Z5RRaRtxckdDY9W9711lB',
#     'id': '6Z5RRaRtxckdDY9W9711lB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273de2177abf7962260fb8f889c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02de2177abf7962260fb8f889c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851de2177abf7962260fb8f889c',
#       'width': 64}],
#     'name': 'Making Music',
#     'release_date': '1987-05-01',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:6Z5RRaRtxckdDY9W9711lB'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nQpHuTbzZE0ZG46dA2L8Q'},
#       'href': 'https://api.spotify.com/v1/artists/3nQpHuTbzZE0ZG46dA2L8Q',
#       'id': '3nQpHuTbzZE0ZG46dA2L8Q',
#       'name': 'Kompozure',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nQpHuTbzZE0ZG46dA2L8Q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2SnnIos3HQgMLqyzT8pYM5'},
#     'href': 'https://api.spotify.com/v1/albums/2SnnIos3HQgMLqyzT8pYM5',
#     'id': '2SnnIos3HQgMLqyzT8pYM5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27362369841a67058b87d6f7183',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0262369841a67058b87d6f7183',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485162369841a67058b87d6f7183',
#       'width': 64}],
#     'name': 'Making Music',
#     'release_date': '2018-03-23',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2SnnIos3HQgMLqyzT8pYM5'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1PTEiCpkzNkLNgMi1LL8JR'},
#       'href': 'https://api.spotify.com/v1/artists/1PTEiCpkzNkLNgMi1LL8JR',
#       'id': '1PTEiCpkzNkLNgMi1LL8JR',
#       'name': 'Laurence Guy',
#       'type': 'artist',
#       'uri': 'spotify:artist:1PTEiCpkzNkLNgMi1LL8JR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2uM2WWarpblam6YIsk9pAo'},
#     'href': 'https://api.spotify.com/v1/albums/2uM2WWarpblam6YIsk9pAo',
#     'id': '2uM2WWarpblam6YIsk9pAo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bda1c2e6f854b16df5f0b420',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bda1c2e6f854b16df5f0b420',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bda1c2e6f854b16df5f0b420',
#       'width': 64}],
#     'name': 'Making Music Is Bad For Your Self Esteem',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:2uM2WWarpblam6YIsk9pAo'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tgApw6eOJlGJ5FElYFeF5'},
#       'href': 'https://api.spotify.com/v1/artists/7tgApw6eOJlGJ5FElYFeF5',
#       'id': '7tgApw6eOJlGJ5FElYFeF5',
#       'name': 'Upbeat Study Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:7tgApw6eOJlGJ5FElYFeF5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1E2x0aClCgaPydDqJFuSdz'},
#     'href': 'https://api.spotify.com/v1/albums/1E2x0aClCgaPydDqJFuSdz',
#     'id': '1E2x0aClCgaPydDqJFuSdz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731a96df252d24846d652af63d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021a96df252d24846d652af63d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511a96df252d24846d652af63d',
#       'width': 64}],
#     'name': 'Making Study Easy',
#     'release_date': '2020-02-25',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:1E2x0aClCgaPydDqJFuSdz'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5P1tdwsQdI6z9MXXfmYRDS'},
#       'href': 'https://api.spotify.com/v1/artists/5P1tdwsQdI6z9MXXfmYRDS',
#       'id': '5P1tdwsQdI6z9MXXfmYRDS',
#       'name': 'Field Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:5P1tdwsQdI6z9MXXfmYRDS'}],
#     'available_markets': ['AU', 'CA', 'NZ', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4SUJnf00X2rb0QilvO6f9w'},
#     'href': 'https://api.spotify.com/v1/albums/4SUJnf00X2rb0QilvO6f9w',
#     'id': '4SUJnf00X2rb0QilvO6f9w',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730f33dd3acecb837c4e4da4fc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020f33dd3acecb837c4e4da4fc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510f33dd3acecb837c4e4da4fc',
#       'width': 64}],
#     'name': 'Making a New World',
#     'release_date': '2020-01-10',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:4SUJnf00X2rb0QilvO6f9w'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/17zRGqeC2wEcDNS3xyHlxO'},
#       'href': 'https://api.spotify.com/v1/artists/17zRGqeC2wEcDNS3xyHlxO',
#       'id': '17zRGqeC2wEcDNS3xyHlxO',
#       'name': 'BigMoney',
#       'type': 'artist',
#       'uri': 'spotify:artist:17zRGqeC2wEcDNS3xyHlxO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7r7oBN2SlRV0ONNr7Gspfr'},
#     'href': 'https://api.spotify.com/v1/albums/7r7oBN2SlRV0ONNr7Gspfr',
#     'id': '7r7oBN2SlRV0ONNr7Gspfr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27374cb8def0a10cc61881e78c3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0274cb8def0a10cc61881e78c3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485174cb8def0a10cc61881e78c3',
#       'width': 64}],
#     'name': 'MMM (Money Making Music)',
#     'release_date': '2020-08-10',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7r7oBN2SlRV0ONNr7Gspfr'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6andpWdsNFMIOgxISRp14o'},
#       'href': 'https://api.spotify.com/v1/artists/6andpWdsNFMIOgxISRp14o',
#       'id': '6andpWdsNFMIOgxISRp14o',
#       'name': 'Chyno with a Why?',
#       'type': 'artist',
#       'uri': 'spotify:artist:6andpWdsNFMIOgxISRp14o'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2j3UbaOGWRE0YKztqhplk4'},
#     'href': 'https://api.spotify.com/v1/albums/2j3UbaOGWRE0YKztqhplk4',
#     'id': '2j3UbaOGWRE0YKztqhplk4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27349ccf2835652913e3a60c7e0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0249ccf2835652913e3a60c7e0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485149ccf2835652913e3a60c7e0',
#       'width': 64}],
#     'name': 'Making Music to Feel at Home',
#     'release_date': '2015-06-15',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:2j3UbaOGWRE0YKztqhplk4'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FIbpgL5x2AO5UsPwLj89I'},
#       'href': 'https://api.spotify.com/v1/artists/2FIbpgL5x2AO5UsPwLj89I',
#       'id': '2FIbpgL5x2AO5UsPwLj89I',
#       'name': 'Soft Sexy Guitar - Chill Out Background Instrumental Music Songs',
#       'type': 'artist',
#       'uri': 'spotify:artist:2FIbpgL5x2AO5UsPwLj89I'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5wPBEiXhpH1j3Wn6TkAGi7'},
#     'href': 'https://api.spotify.com/v1/albums/5wPBEiXhpH1j3Wn6TkAGi7',
#     'id': '5wPBEiXhpH1j3Wn6TkAGi7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739de63ba992e1feb445cd01b0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029de63ba992e1feb445cd01b0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519de63ba992e1feb445cd01b0',
#       'width': 64}],
#     'name': 'Love Making Music',
#     'release_date': '2019-05-29',
#     'release_date_precision': 'day',
#     'total_tracks': 25,
#     'type': 'album',
#     'uri': 'spotify:album:5wPBEiXhpH1j3Wn6TkAGi7'},
#    {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/04NquZ9EQ2Z5N0R49cJ6W8'},
#     'href': 'https://api.spotify.com/v1/albums/04NquZ9EQ2Z5N0R49cJ6W8',
#     'id': '04NquZ9EQ2Z5N0R49cJ6W8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cf17a81153306bcee659696e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cf17a81153306bcee659696e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cf17a81153306bcee659696e',
#       'width': 64}],
#     'name': 'Erotic Lounge Obsession (Best of Sensual Chillout Love Making Music for Intimate Moments and Sexy Relaxation)',
#     'release_date': '2014-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 33,
#     'type': 'album',
#     'uri': 'spotify:album:04NquZ9EQ2Z5N0R49cJ6W8'},
#    {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0pEZ1F9UB4pEP3TNzZAOu6'},
#     'href': 'https://api.spotify.com/v1/albums/0pEZ1F9UB4pEP3TNzZAOu6',
#     'id': '0pEZ1F9UB4pEP3TNzZAOu6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736f08f379f7b7f5fb9e4aa3cb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026f08f379f7b7f5fb9e4aa3cb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516f08f379f7b7f5fb9e4aa3cb',
#       'width': 64}],
#     'name': 'Love Making Music: Best Lounge Sexy Music',
#     'release_date': '2012-11-19',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:0pEZ1F9UB4pEP3TNzZAOu6'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0enY9T3PPR23WeDoTy9CIy'},
#       'href': 'https://api.spotify.com/v1/artists/0enY9T3PPR23WeDoTy9CIy',
#       'id': '0enY9T3PPR23WeDoTy9CIy',
#       'name': 'Fred',
#       'type': 'artist',
#       'uri': 'spotify:artist:0enY9T3PPR23WeDoTy9CIy'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3rVOPOzEVl7te6lO8gNjsO'},
#     'href': 'https://api.spotify.com/v1/albums/3rVOPOzEVl7te6lO8gNjsO',
#     'id': '3rVOPOzEVl7te6lO8gNjsO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730864fa3fdb67acd1cc3e3d4d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020864fa3fdb67acd1cc3e3d4d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510864fa3fdb67acd1cc3e3d4d',
#       'width': 64}],
#     'name': "Making music so you don't have to",
#     'release_date': '2005-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:3rVOPOzEVl7te6lO8gNjsO'},
#    {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/577Ps0MKqWfxGcjomGk5MF'},
#     'href': 'https://api.spotify.com/v1/albums/577Ps0MKqWfxGcjomGk5MF',
#     'id': '577Ps0MKqWfxGcjomGk5MF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c06cff6244acccb9bd560bd6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c06cff6244acccb9bd560bd6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c06cff6244acccb9bd560bd6',
#       'width': 64}],
#     'name': 'Baby Making Music',
#     'release_date': '2019-01-18',
#     'release_date_precision': 'day',
#     'total_tracks': 30,
#     'type': 'album',
#     'uri': 'spotify:album:577Ps0MKqWfxGcjomGk5MF'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wP231gwe7anNvT4ovC42D'},
#       'href': 'https://api.spotify.com/v1/artists/5wP231gwe7anNvT4ovC42D',
#       'id': '5wP231gwe7anNvT4ovC42D',
#       'name': 'Musical Spa',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wP231gwe7anNvT4ovC42D'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2uHgTjOOu4o2MJALNHBc3i'},
#     'href': 'https://api.spotify.com/v1/albums/2uHgTjOOu4o2MJALNHBc3i',
#     'id': '2uHgTjOOu4o2MJALNHBc3i',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739fa7ed8af1e325f5ef26050a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029fa7ed8af1e325f5ef26050a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519fa7ed8af1e325f5ef26050a',
#       'width': 64}],
#     'name': 'Love Making Music',
#     'release_date': '2010-08-02',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:2uHgTjOOu4o2MJALNHBc3i'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CiVPdtI0h16037yC3Ibdl'},
#       'href': 'https://api.spotify.com/v1/artists/3CiVPdtI0h16037yC3Ibdl',
#       'id': '3CiVPdtI0h16037yC3Ibdl',
#       'name': 'Entre Mujeres',
#       'type': 'artist',
#       'uri': 'spotify:artist:3CiVPdtI0h16037yC3Ibdl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4fFosKtp3ZSylWfJJw3sxz'},
#     'href': 'https://api.spotify.com/v1/albums/4fFosKtp3ZSylWfJJw3sxz',
#     'id': '4fFosKtp3ZSylWfJJw3sxz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735da43d6a5bc54fa9955e9784',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025da43d6a5bc54fa9955e9784',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515da43d6a5bc54fa9955e9784',
#       'width': 64}],
#     'name': 'Women Making Music Across Borders',
#     'release_date': '2013-04-30',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4fFosKtp3ZSylWfJJw3sxz'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3R1RAIEPzoRYlG4OpgS2IL'},
#       'href': 'https://api.spotify.com/v1/artists/3R1RAIEPzoRYlG4OpgS2IL',
#       'id': '3R1RAIEPzoRYlG4OpgS2IL',
#       'name': 'Erotic Music Zone',
#       'type': 'artist',
#       'uri': 'spotify:artist:3R1RAIEPzoRYlG4OpgS2IL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3gLJB71n26mMhJx7CLbsq5'},
#     'href': 'https://api.spotify.com/v1/albums/3gLJB71n26mMhJx7CLbsq5',
#     'id': '3gLJB71n26mMhJx7CLbsq5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cd7040a85f9f2b2d08256f07',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cd7040a85f9f2b2d08256f07',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cd7040a85f9f2b2d08256f07',
#       'width': 64}],
#     'name': 'Essence of Erotic Music: Intimate Moments, Hot Foreplay, Love Making Music, Romantic Night, Tantric Sex Chillout, Sensual Massage, Red Passion Lounge',
#     'release_date': '2016-11-25',
#     'release_date_precision': 'day',
#     'total_tracks': 30,
#     'type': 'album',
#     'uri': 'spotify:album:3gLJB71n26mMhJx7CLbsq5'},
#    {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6GATnxT5Q2OYIRIlImeD7M'},
#     'href': 'https://api.spotify.com/v1/albums/6GATnxT5Q2OYIRIlImeD7M',
#     'id': '6GATnxT5Q2OYIRIlImeD7M',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27313fec2dfda7c6a7fe04bdf51',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0213fec2dfda7c6a7fe04bdf51',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485113fec2dfda7c6a7fe04bdf51',
#       'width': 64}],
#     'name': 'Erotism: Love Making Music, Erotic Moments, Hot Sexual Healing Music, Smooth Lounge Sexy Music Playlist for Love & Intimacy',
#     'release_date': '2013-04-27',
#     'release_date_precision': 'day',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:6GATnxT5Q2OYIRIlImeD7M'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69fIqoJWkg7SKHVxbB8n0g'},
#       'href': 'https://api.spotify.com/v1/artists/69fIqoJWkg7SKHVxbB8n0g',
#       'id': '69fIqoJWkg7SKHVxbB8n0g',
#       'name': 'Devon Morgan',
#       'type': 'artist',
#       'uri': 'spotify:artist:69fIqoJWkg7SKHVxbB8n0g'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5kBPnWlaaqCON8F0x59jrR'},
#       'href': 'https://api.spotify.com/v1/artists/5kBPnWlaaqCON8F0x59jrR',
#       'id': '5kBPnWlaaqCON8F0x59jrR',
#       'name': 'Sleepy Time Ghost',
#       'type': 'artist',
#       'uri': 'spotify:artist:5kBPnWlaaqCON8F0x59jrR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1OP7Bd9VFNsTOCDezXOD7E'},
#     'href': 'https://api.spotify.com/v1/albums/1OP7Bd9VFNsTOCDezXOD7E',
#     'id': '1OP7Bd9VFNsTOCDezXOD7E',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27383396e5850775a9af56f311c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0283396e5850775a9af56f311c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485183396e5850775a9af56f311c',
#       'width': 64}],
#     'name': 'Keep On Making Music',
#     'release_date': '2020-02-21',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:1OP7Bd9VFNsTOCDezXOD7E'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Kjrh0Tl4Ca9BSqhG0qiKA'},
#       'href': 'https://api.spotify.com/v1/artists/5Kjrh0Tl4Ca9BSqhG0qiKA',
#       'id': '5Kjrh0Tl4Ca9BSqhG0qiKA',
#       'name': 'Café La Nuit de Paris',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Kjrh0Tl4Ca9BSqhG0qiKA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7B9CeobPTTgijU7u3dUfoU'},
#       'href': 'https://api.spotify.com/v1/artists/7B9CeobPTTgijU7u3dUfoU',
#       'id': '7B9CeobPTTgijU7u3dUfoU',
#       'name': 'Lounge Music Café',
#       'type': 'artist',
#       'uri': 'spotify:artist:7B9CeobPTTgijU7u3dUfoU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0OvfJPgLqarUHCb7YOKrIu'},
#     'href': 'https://api.spotify.com/v1/albums/0OvfJPgLqarUHCb7YOKrIu',
#     'id': '0OvfJPgLqarUHCb7YOKrIu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27322ee3c5811e75da4aba22c1d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0222ee3c5811e75da4aba22c1d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485122ee3c5811e75da4aba22c1d',
#       'width': 64}],
#     'name': 'Lounge Sex Seduction – Amour à Paris, Buddha Lounge Café Love Making Music',
#     'release_date': '2018-11-18',
#     'release_date_precision': 'day',
#     'total_tracks': 22,
#     'type': 'album',
#     'uri': 'spotify:album:0OvfJPgLqarUHCb7YOKrIu'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6InGPBuMJFUdPYgAJQKWW0'},
#       'href': 'https://api.spotify.com/v1/artists/6InGPBuMJFUdPYgAJQKWW0',
#       'id': '6InGPBuMJFUdPYgAJQKWW0',
#       'name': "Makin' Music Rockin' Rhythms",
#       'type': 'artist',
#       'uri': 'spotify:artist:6InGPBuMJFUdPYgAJQKWW0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5s9MSyBpztKEaeiJWn7NwN'},
#     'href': 'https://api.spotify.com/v1/albums/5s9MSyBpztKEaeiJWn7NwN',
#     'id': '5s9MSyBpztKEaeiJWn7NwN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e2de32d7a85613d76e9066e4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e2de32d7a85613d76e9066e4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e2de32d7a85613d76e9066e4',
#       'width': 64}],
#     'name': "Jumpin' in the Leaves",
#     'release_date': '2016-09-01',
#     'release_date_precision': 'day',
#     'total_tracks': 23,
#     'type': 'album',
#     'uri': 'spotify:album:5s9MSyBpztKEaeiJWn7NwN'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Making+Music&type=album&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 1550}}

# %%
spotify.get_artist('2MphKCPv2wbV61u03gKP4i')
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/2MphKCPv2wbV61u03gKP4i'},
#  'followers': {'href': None, 'total': 166},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/artists/2MphKCPv2wbV61u03gKP4i',
#  'id': '2MphKCPv2wbV61u03gKP4i',
#  'images': [],
#  'name': 'Zakir Hussain, Krishna Bhatt',
#  'popularity': 4,
#  'type': 'artist',
#  'uri': 'spotify:artist:2MphKCPv2wbV61u03gKP4i'}

# %%
spotify.get_album('5CfytRni4jhBrwM2MdPg1N')
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#    'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#    'id': '1ThoqLcyIYvZn7iWbj8fsj',
#    'name': 'Bill Withers',
#    'type': 'artist',
#    'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#  'available_markets': ['AD',
#   'AE',
#   'AL',
#   'AR',
#   'AT',
#   'AU',
#   'BA',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'BY',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HR',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'KZ',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MK',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'SA',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'UA',
#   'US',
#   'UY',
#   'VN',
#   'XK',
#   'ZA'],
#  'copyrights': [{'text': '(P) 1975 Sony Music Entertainment', 'type': 'P'}],
#  'external_ids': {'upc': '884977267990'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/5CfytRni4jhBrwM2MdPg1N'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/5CfytRni4jhBrwM2MdPg1N',
#  'id': '5CfytRni4jhBrwM2MdPg1N',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2736387564c694f2d017a3554b6',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e026387564c694f2d017a3554b6',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048516387564c694f2d017a3554b6',
#    'width': 64}],
#  'label': 'Legacy Recordings',
#  'name': 'Making Music',
#  'popularity': 37,
#  'release_date': '1975-11-08',
#  'release_date_precision': 'day',
#  'total_tracks': 10,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/5CfytRni4jhBrwM2MdPg1N/tracks?offset=0&limit=50',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#       'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#       'id': '1ThoqLcyIYvZn7iWbj8fsj',
#       'name': 'Bill Withers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 237186,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5CMqPxGLbwtNl5gtB3Me3m'},
#     'href': 'https://api.spotify.com/v1/tracks/5CMqPxGLbwtNl5gtB3Me3m',
#     'id': '5CMqPxGLbwtNl5gtB3Me3m',
#     'is_local': False,
#     'name': 'I Wish You Well',
#     'preview_url': 'https://p.scdn.co/mp3-preview/81e16fbab43c880bb3a71d733679bc2dae506d48?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5CMqPxGLbwtNl5gtB3Me3m'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#       'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#       'id': '1ThoqLcyIYvZn7iWbj8fsj',
#       'name': 'Bill Withers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 142386,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/65ZDuyhiQ4xfC7qW6OWWUa'},
#     'href': 'https://api.spotify.com/v1/tracks/65ZDuyhiQ4xfC7qW6OWWUa',
#     'id': '65ZDuyhiQ4xfC7qW6OWWUa',
#     'is_local': False,
#     'name': 'The Best You Can',
#     'preview_url': 'https://p.scdn.co/mp3-preview/6bcc6c8c81aec21b59c3e572611f04f5480c598d?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:65ZDuyhiQ4xfC7qW6OWWUa'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#       'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#       'id': '1ThoqLcyIYvZn7iWbj8fsj',
#       'name': 'Bill Withers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 383680,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5wBB0bSW7UOPUqma2gi9TZ'},
#     'href': 'https://api.spotify.com/v1/tracks/5wBB0bSW7UOPUqma2gi9TZ',
#     'id': '5wBB0bSW7UOPUqma2gi9TZ',
#     'is_local': False,
#     'name': 'Make Love to Your Mind',
#     'preview_url': 'https://p.scdn.co/mp3-preview/697f9e762952b20729446ecfeea9d835082e4381?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5wBB0bSW7UOPUqma2gi9TZ'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#       'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#       'id': '1ThoqLcyIYvZn7iWbj8fsj',
#       'name': 'Bill Withers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 156133,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4RZ6BHVShn57XFVZWqxNz1'},
#     'href': 'https://api.spotify.com/v1/tracks/4RZ6BHVShn57XFVZWqxNz1',
#     'id': '4RZ6BHVShn57XFVZWqxNz1',
#     'is_local': False,
#     'name': 'I love You Dawn',
#     'preview_url': 'https://p.scdn.co/mp3-preview/7933392fb5b19f7b95fa761ac543e5b337c27c22?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4RZ6BHVShn57XFVZWqxNz1'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#       'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#       'id': '1ThoqLcyIYvZn7iWbj8fsj',
#       'name': 'Bill Withers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 315440,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0j7v09qthN0N9BNti8AiQl'},
#     'href': 'https://api.spotify.com/v1/tracks/0j7v09qthN0N9BNti8AiQl',
#     'id': '0j7v09qthN0N9BNti8AiQl',
#     'is_local': False,
#     'name': "She's Lonely",
#     'preview_url': 'https://p.scdn.co/mp3-preview/bffd55a03bb8ef61e49b5158328ae679e5b0ab90?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0j7v09qthN0N9BNti8AiQl'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#       'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#       'id': '1ThoqLcyIYvZn7iWbj8fsj',
#       'name': 'Bill Withers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 284946,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/626xUznOcSJ5ufa8WtX0IB'},
#     'href': 'https://api.spotify.com/v1/tracks/626xUznOcSJ5ufa8WtX0IB',
#     'id': '626xUznOcSJ5ufa8WtX0IB',
#     'is_local': False,
#     'name': 'Sometimes A Song',
#     'preview_url': 'https://p.scdn.co/mp3-preview/8f8234de1303a1ac37044d72a1bcf651227cd069?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:626xUznOcSJ5ufa8WtX0IB'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#       'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#       'id': '1ThoqLcyIYvZn7iWbj8fsj',
#       'name': 'Bill Withers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 342893,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3iZcHn4l5dmedBISBFHpxJ'},
#     'href': 'https://api.spotify.com/v1/tracks/3iZcHn4l5dmedBISBFHpxJ',
#     'id': '3iZcHn4l5dmedBISBFHpxJ',
#     'is_local': False,
#     'name': 'Paint Your Little Picture',
#     'preview_url': 'https://p.scdn.co/mp3-preview/1f37bdc539d35479ed023fecd1e32032314358b7?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:3iZcHn4l5dmedBISBFHpxJ'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#       'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#       'id': '1ThoqLcyIYvZn7iWbj8fsj',
#       'name': 'Bill Withers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 192693,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6n394oTmJIT1oI8cWNgIwU'},
#     'href': 'https://api.spotify.com/v1/tracks/6n394oTmJIT1oI8cWNgIwU',
#     'id': '6n394oTmJIT1oI8cWNgIwU',
#     'is_local': False,
#     'name': 'Family Table',
#     'preview_url': 'https://p.scdn.co/mp3-preview/5c35a36e88a541a0bf5a0deccc495db1d1d1b990?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:6n394oTmJIT1oI8cWNgIwU'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#       'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#       'id': '1ThoqLcyIYvZn7iWbj8fsj',
#       'name': 'Bill Withers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 243813,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1bfivmkmX0CIQs5Djl2IM0'},
#     'href': 'https://api.spotify.com/v1/tracks/1bfivmkmX0CIQs5Djl2IM0',
#     'id': '1bfivmkmX0CIQs5Djl2IM0',
#     'is_local': False,
#     'name': "Don't You Want to Stay?",
#     'preview_url': 'https://p.scdn.co/mp3-preview/0fd588066bdccb789008b907e55ade768624b429?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:1bfivmkmX0CIQs5Djl2IM0'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ThoqLcyIYvZn7iWbj8fsj'},
#       'href': 'https://api.spotify.com/v1/artists/1ThoqLcyIYvZn7iWbj8fsj',
#       'id': '1ThoqLcyIYvZn7iWbj8fsj',
#       'name': 'Bill Withers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ThoqLcyIYvZn7iWbj8fsj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 331013,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7aIiWbUU4oPVSH9J3EaT5V'},
#     'href': 'https://api.spotify.com/v1/tracks/7aIiWbUU4oPVSH9J3EaT5V',
#     'id': '7aIiWbUU4oPVSH9J3EaT5V',
#     'is_local': False,
#     'name': 'Hello Like Before',
#     'preview_url': 'https://p.scdn.co/mp3-preview/b145c904ea3a2861aa8925f6d92c01840b081eb8?cid=4eaaf1ab67a346ff909b0ec7a639ff40',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7aIiWbUU4oPVSH9J3EaT5V'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 10},
#  'type': 'album',
#  'uri': 'spotify:album:5CfytRni4jhBrwM2MdPg1N'}
